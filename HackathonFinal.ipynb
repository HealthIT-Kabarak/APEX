# %% [markdown]
# # 1. **DATA ENGINEERING PROCESS**

# %%
#importing libraries and tools needed
import pandas as pd

# %%
# Load the CSV file
df = pd.read_csv("/content/data.csv")

# %% [markdown]
# Explatory Data Analysis

# %%
#gives the number of rows and columns....its also the size/dimensions of the dataset
df.shape
# Out:
# (60, 55)

# %%
#prints the number of rows and columns in the dataset
num_rows, num_cols = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_cols)
# Out:
# Number of rows: 60
# Number of columns: 55

# %%
#shows the data types of the data in the dataset
print(df.dtypes)

# %%
# Check for missing values
missing_values = df.isnull().sum()

# Print the results
print(missing_values)

# %%
#checks for duplicate values
num_duplicates = duplicates.sum()
print("Number of duplicate rows:", num_duplicates)

# %%
#shows the columns in the dataset
df.columns

# %% [markdown]
# ## Univariate Analysis

# %%
#evaluating a single variable in isolation
variable = df['Baringo County']

# %%
mean = variable.mean()
median = variable.median()
mode = variable.mode()
std_dev = variable.std()
variance = variable.var()
range = variable.max() - variable.min()

print("Mean:", mean)
print("Median:", median)
#print("Mode:", mode)
print("Standard deviation:", std_dev)
print("Variance:", variance)
print("Range:", range)
# Out:
# Mean: 3143.8
# Median: 2783.0
# Standard deviation: 1805.3846747241466
# Variance: 3259413.823728813
# Range: 9766.0

# %%
#This can help you identify outliers and understand the shape of the distribution.
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(variable, kde=True)
plt.show()

sns.boxplot(variable)
plt.show()

sns.kdeplot(variable)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Bivariate Analysis
# Analysing the relationship between two variables

# %%
#assigning the columns as variables
variable1 = df['Nakuru County']
variable2 = df['Baringo County']

# %%
correlation_coefficient = variable1.corr(variable2)

print("Correlation coefficient:", correlation_coefficient)
#This means that as one variable increases, the other variable tends to decrease slightly. 
#However, the correlation coefficient value of -0.051765049913442975 is close to zero, which suggests 
#that the relationship between the two variables is not very strong.
# Out:
# Correlation coefficient: -0.051765049913442975

# %% [markdown]
# ## Multivariate Analysis

# %%
variables = df[['periodid', 'periodname', 'periodcode', 'perioddescription', 'dataid',
       'dataname', 'datacode', 'datadescription', 'Baringo County',
       'Bomet County', 'Bungoma County', 'Busia County',
       'Elgeyo Marakwet County', 'Embu County', 'Garissa County',
       'Homa Bay County', 'Isiolo County', 'Kajiado County', 'Kakamega County',
       'Kericho County', 'Kiambu County', 'Kilifi County', 'Kirinyaga County',
       'Kisii County', 'Kisumu County', 'Kitui County', 'Kwale County',
       'Laikipia County', 'Lamu County', 'Machakos County', 'Makueni County',
       'Mandera County', 'Marsabit County', 'Meru County', 'Migori County',
       'Mombasa County', 'Muranga County', 'Nairobi County', 'Nakuru County',
       'Nandi County', 'Narok County', 'Nyamira County', 'Nyandarua County',
       'Nyeri County', 'Samburu County', 'Siaya County', 'Taita Taveta County',
       'Tana River County', 'Tharaka Nithi County', 'Trans Nzoia County',
       'Turkana County', 'Uasin Gishu County', 'Vihiga County', 'Wajir County',
       'West Pokot County']]

# %%
#calculating the corelational matrix
correlation_matrix = variables.corr()

print("Correlation matrix:\n", correlation_matrix)

# %%
#visualizing the corelation matrix
import seaborn as sns

sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
#replacing missing values with the mean of the variable
numeric_variables = numeric_variables.fillna(numeric_variables.mean())

# %%
#selecting numeric values from the dataset
numeric_variables = variables.select_dtypes(include=['float64', 'int64'])

# %%
#using Principle Component Analysis to identify important variables
pca = PCA(n_components=2)
principal_components = pca.fit_transform(numeric_variables)

principal_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

# %% [markdown]
# # **2. DATA MODELLING PROCESS**
